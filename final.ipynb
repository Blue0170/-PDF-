# %%
# import os
# from PyPDF2 import PdfFileReader
# from PyPDF2 import PdfFileWriter
# import importlib
# import sys
# import time
# import xlwt
# importlib.reload(sys)
# time1 = time.time()
# from pdfminer.layout import LAParams, LTTextBox, LTTextLine

# # from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
# from pdfminer.converter import PDFPageAggregator
# from pdfminer.layout import LTTextBoxHorizontal, LAParams
# from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
# from openpyxl import Workbook
# from io import BytesIO
# from io import StringIO
import pandas as pd
import numpy as np

# %%
# from pdfminer.pdfdocument import PDFDocument
# import pandas as pd
# import pdfplumber
# # from pdfminer.pdfparser import PDFParser, PDFDocument
# pdffile="C:/Users/USER/Desktop/2013/2013_1201.pdf"     #pdf檔路徑及檔名
# pdf = pdfplumber.open(pdffile)
# p0 = pdf.pages[0]
# text=p0.extract_text()       #讀文字
# print(text)

# %%
import xlwings as xw
import glob
read_files = glob.glob(r'C:/Users/USER/Desktop/2014/*')
print(read_files)


#--------------------------------------------------------------------------
import pdfplumber
# a = []
iname = []
num = []
d = []
for line in read_files:
    line = line.split("/")
    num.append(line )
print(num[0])

for j in range(0,len(read_files)):
    try:
   
        print("----------------------------------------------------------------------------------------------------")
        pdf = pdfplumber.open(read_files[j])
        print(j)
        try:
            
            a = [] 
            
            for i in range(20):
#                 
                  
                pg = pdf.pages[i]
                text = pg.extract_text()
#                 print(text)
                a.append(text)

        except AttributeError as ae:
            print(ae)
                
        except:
            print('e')
        finally:
#             print(a)
            if a is not None:
                a = filter(None,a)
                b = ''
                # print(b.join(a))
                c = b.join(a)
#                 print(c)
                pos1 = c.find("致股東報告書")
                pos2 = c.find("公司簡介")
                pos3 = c.find("致股東報告書",pos1+1)
                pos4 = c.find("公司簡介",pos3+1)
                print(pos3,pos4)
                if pos3!=pos4:    
                    d.append(c[pos3:pos4])
                    print(c[pos3:pos4])
                    iname.append(num[j][4][10:14])
                    print(iname)
            
    
    
    except:
        print("read error")
      
#    finally:
#     else:
        
        
#     finally:
#         if a is not None:
#             a = filter(None,a)
#             b = ''
#             # print(b.join(a))
#             c = b.join(a)
#             pos1 = c.find("致股東報告書")
#             pos2 = c.find("公司簡介")
#             pos3 = c.find("致股東報告書",pos1+1)
#             pos4 = c.find("公司簡介",pos3+1)
#             print(pos3,pos4)
#             if pos3!=pos4:    
#                 d.append(c[pos3:pos4])
#                 print(d)
#                 iname.append(num[j][4][10:14])
#                 print(iname)
# Out:
# ['C:/Users/USER/Desktop/2014\\2014_2337.pdf', 'C:/Users/USER/Desktop/2014\\2014_2338.pdf']
# ['C:', 'Users', 'USER', 'Desktop', '2014\\2014_2337.pdf']
# ----------------------------------------------------------------------------------------------------
# 0
# 5925 7726
# 致股東報告書
#
# 103 12
# 民國 年，旺宏營收較前一年微幅增加，但由於 吋晶圓廠仍處於折舊攤提及
# (Spansion)
# 產能轉換費用較高的階段，加上受到與競爭同業飛索公司 間專利訴訟之衝
# 103 41% 12
# 擊，致營業成果未達預期。然而，民國 年營業毛利已較前一年增加 ，顯示
# 吋晶圓廠生產效能漸入佳境。何況，旺宏與飛索之爭議亦已經調解成功，其結論不僅
# 有利於旺宏之財務與業務，更令旺宏堅強之智慧財產權與訴訟攻防實力享譽國際。日
#
# 後，旺宏將加速腳步，期能於最快時間內，達成獲利的目標。
#
# 103 224.14
# 民國 年經營實績為：全年合併營收淨額為新台幣 億元，較前一年增加
# 1% 93% 12% 75.65
# ，全年產能利用率約為 ，平均毛利率 ；全年折舊及攤銷為新台幣 億
# 64.83 1.84 2.93
# 元，稅後淨損新台幣 億元，每股虧損 元，但是營運活動產生的現金是
# EBITDA 13.77
# 億元、 為新台幣 億元，顯示公司是淨現金流入，具有健康的財務流動性
# 76.36 49%
# 與獲利能力。期末約當現金為新台幣 億元，負債比率為 ，仍是合理的負債水
# 93.02
# 準。存貨為新台幣 億元，足以支應未來業績需求。
#
# 旺宏長期致力於非揮發性記憶體技術與產品之創新與研發，並重視智慧財產權之
# 103
# 保護，透過各國專利之申請，保障旺宏自有的關鍵技術與豐碩的研發成果。民國 年
# 436 14% 5,716
# 共獲得 件專利，較前一年成長 ，目前累計擁有全球 件專利，堅強的智財
#
# 權與訴訟實力，更加鞏固旺宏在全球非揮發性記憶體之領導地位。
#
# (ROM) 45 ROM
# 在唯讀記憶體 方面，客戶需求尚稱穩定， 奈米產品佔去年第四季 營
# 84% 32 16/32Gb NOR (NOR
# 收的 ， 奈米 產品將於今年第一季開始量產；在 型快閃記憶體
# Flash) 3 2 75
# 方面，出貨量持續成長，自去年第二季在世界排名已由第 位提升至第 位，
# NOR Flash 34% 55 3V dual-quad serial 256/512 Mb
# 奈米產品佔去年第四季 營收的 ， 奈米
# NOR SLC NAND Flash
# 產品已經向車用電子客戶送樣認證； 方面，去年推出後，由於產
# 36 12
# 品品質優異，客戶需求特別殷切，今年將以 奈米 吋廠產能來供應。同時開發的
# NAND-based MCP(Multi-Chip Package) NAND DRAM
# 產品，成功結合 與 晶片，已於去
# M2M
# 年第四季送樣認證，預計今年開始量產，將滿足 市場廣泛應用之需求。
# - 1 -
#
#
# 旺宏向來遵守法令並以客戶為尊，除主動遵循「電子業行為準則」的規範外，並積
# 極推動節能、節水、減碳與減廢工作，及投入各類污染防治設備之更新與維護，以持續
# 朝高效率低污染的綠色晶圓廠目標邁進；旺宏的產品，也持續獲得國際知名廠商頒發綠
# 色產品證書。此外，我們也呼應供應鏈夥伴共同推動「企業社會責任」，為社會的進步
#
# 及環境保護盡一份心力。
#
# 104
# 展望民國 年，我們在穩定的晶圓廠產能與先進的自有技術之下，規劃資本支出
# 17
# 約新台幣 億元，主要用於既有設備汰舊換新及製程提升。在長時間的市場佈局與深
# / /
# 耕後，物聯網 穿戴裝置、無線通信、汽車 工業等三大領域的產品將是今年驅動營運成
# NOR
# 長的主要動力，其中包括比同業更具競爭力之新系列高效能、寬電壓、超低功耗的
# Flash SLC NAND Flash MCP SLC NAND
# 記憶體解決方案、 和 產品等。至於新開發成功的
# Flash
# 全系列產品之出貨及晶圓代工之業務可望放量成長，使整體營運向上提升。然而，
# 面對嚴峻的經濟環境與沉重的折舊負擔，我們將努力開源節流，以維持健全的財務結
# 構；強化投資管理，以達到集團整合綜效；持續強化及加速先進非揮發性記憶體技術與
# 產品，以根本增進旺宏競爭優勢，更加速開發相關產品的解決方案及提供客戶更完備的
#
# 產品組合，向世界排名領先地位邁進。
#
# 最後，感謝各位股東長期的支持與信任，相信在全體同仁的努力下，我們必能穩
# 健渡過晶圓廠必經的折舊陣痛期，再次繳出亮麗成績，以達到股東、員工及客戶三贏
#
# 的成果。
#
#
#
# 董事長
#
# 總經理
#
#
# - 2 -
#
#
# 貳、
# ['2337']
# ----------------------------------------------------------------------------------------------------
# read error

# %%
wb = xw.Book(r'C:/Users/USER/Desktop/pdf_parser0914.xlsx')
# # # 從 檔案裡找出名為 2330 的試算表，存入 tsmc_sheet 這個變數裏
pp = wb.sheets['工作表1']
# # 讓 xlwings 動態開啟一個新的 Excel 檔案，並將該檔案存入 workbook 變數
# # workbook = xw.Book()
# # 若你沒有開啟你的 Excel, 這行可能會跑的慢一點，請耐心等待，讓子彈飛一會兒～
# # 到 workbook 代表的 excel 檔案下，開啓名爲 '工作表1' 的試算表

# # col = ["更","好","的","未","來"]
# ID = ["1101","1102","1103","1104","1105"]
# # print(len(col))
# # # 將該試算表裏面的 A1 儲存格的值設定成 "Hello World!"
for s in range(1,len(d)+1):
    pp.cells(s, "A").value = d[s-1]
    pp.cells(s, "B").value = iname[s-1]

# %%
import openpyxl
from openpyxl import Workbook
book = openpyxl.Workbook()
# #建立一個工作簿
# sheet1 = book.Workbook[0]

# col = ["更","好","的","未","來"]

# i = 0
# # 遍历方式2：

# for row in sheet1["A1":"A"+int(len(col))]:
#     for i in range(0,len(col)):
#         for cell in row:
#             cell.value =col[i] 

# book.save("C:/Users/USER/Desktop/pdf_parser0718.xlsx")

# %%
a = ["1","2","3",None]
a = filter(None,a)
b = ""
c = b.join(a)
c
# filter(None, ['a', None, 'c'])
# Out:
# '123'
